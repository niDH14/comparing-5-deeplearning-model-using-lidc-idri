# %%
import tensorflow as tf # Imports tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization,Embedding,TimeDistributed
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ReLU, LSTM,Bidirectional,Attention,Concatenate,concatenate
from tensorflow.keras import regularizers, optimizers,losses
from tensorflow.keras.layers import DepthwiseConv2D,Add, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D,MultiHeadAttention
from tensorflow.keras.layers import Activation,ActivityRegularization, AvgPool2D, LeakyReLU, Conv2DTranspose
from tensorflow.keras.metrics import Accuracy,Recall,Precision,AUC,TruePositives,TrueNegatives,FalseNegatives,FalsePositives, SpecificityAtSensitivity,SensitivityAtSpecificity
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras.utils import np_utils
import numpy as np
import pandas as pd 
import matplotlib
import seaborn as sns
import sklearn
#import imblearn
#from keras.optimizers import Adam
import matplotlib.pyplot as plt 
import time
import os
import sklearn.metrics as m
from glob import glob
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import skimage.io
import skimage.color
import skimage.filters

# %%
gr_shape=(128,128,1)
img_shape = (128,128,3)
input_dir="C:/nidhin/abu project/LIDC-IDRI-slices"
images=[]
masks=[]
y=[]
Thres = 5000/255

# %% [markdown]
# In the provided code, the following preprocessing steps are performed:
#
# 1. Loading Images and Masks:
#    - Images and masks are loaded from the specified directories using `image.load_img()` from the Keras preprocessing module. They are resized to the `img_shape`.
#    - The images are stored in the `images` list, and the masks are stored in separate lists (`mask0`, `mask1`, `mask2`, `mask3`).
#
# 2. Processing Masks and Labels:
#    - For each nodule, the white pixel sum is computed for each mask (`mask0`, `mask1`, `mask2`, `mask3`).
#    - If the count of white pixels exceeds the threshold (`Thres`) for more than 2 masks, it is labeled as 1 (positive), and the mask with the maximum white pixel sum is chosen. Otherwise, it is labeled as 0 (negative), and the mask with the minimum white pixel sum is chosen.
#    - The images, masks, and labels are stored in lists (`images`, `masks`, `y`).
#
# 3. Normalization:
#    - Images and masks are divided by 255 to normalize pixel values between 0 and 1.
#
# 4. Handling Missing Values:
#    - Any NaN values in images and masks are replaced with 0 using `np.nan_to_num()`.
#
# 5. Data Augmentation:
#    - No explicit data augmentation is performed in this snippet.
#
# 6. Data Concatenation:
#    - Additional data is added to the training set (`x_train_added`, `y_train_added`) by appending a portion of the test set (`x_test`, `y_test`).
#
# Overall, the preprocessing in this code involves loading images and masks, processing masks to determine labels, normalizing the pixel values, handling missing values, and concatenating data for training.

# %%
# Iterate over patients in the input directory
for patient in os.listdir(input_dir):
    # Check if the item is a directory
    patient_dir = os.path.join(input_dir, patient)
    if not os.path.isdir(patient_dir):
        continue

    # Break loop if images list exceeds 10000
    if len(images) > 10000:
        break

    # Iterate over nodules in the patient directory
    for nodule in os.listdir(patient_dir):
        nodule_dir = os.path.join(patient_dir, nodule)
        if not os.path.isdir(nodule_dir):
            continue

        mask0 = []
        mask1 = []
        mask2 = []
        mask3 = []

        # Load images
        for filename in glob(os.path.join(nodule_dir, 'images', '*.png')):
            img = image.load_img(filename, target_size=img_shape)
            img = np.asarray(img)
            images.append(img)

        # Load masks
        for i, mask_dir in enumerate([mask0, mask1, mask2, mask3]):
            for filename in glob(os.path.join(nodule_dir, f'mask-{i}', '*.png')):
                img = image.load_img(filename, target_size=img_shape)
                img = np.asarray(img)
                mask_dir.append(img)

        # Process masks and labels
        for i in range(len(mask0)):
            white_sum = np.array([mask.sum() for mask in [mask0[i], mask1[i], mask2[i], mask3[i]]])
            cnt = np.sum(white_sum > Thres)
            if cnt > 2:
                y.append(1)
                max_index = white_sum.argmax()
                masks.append([mask0[i], mask1[i], mask2[i], mask3[i]][max_index])
            else:
                y.append(0)
                min_index = white_sum.argmin()
                masks.append([mask0[i], mask1[i], mask2[i], mask3[i]][min_index])

# %% [markdown]
# The code snippet provided iterates over patients in a directory (`input_dir`) and processes their images and masks. Here's how `label` is created based on the masks:
#
# - For each patient, it loads images and masks associated with nodules.
# - It then calculates the sum of white pixels in each mask (`mask0`, `mask1`, `mask2`, `mask3`).
# - If the count of white pixels exceeding a threshold (`Thres`) is greater than 2, it appends `1` to the label list `label`. Otherwise, it appends `0`.
# - Additionally, it selects the mask with the maximum sum of white pixels if the count is greater than 2; otherwise, it selects the mask with the minimum sum of white pixels.
# - The selected masks are appended to the `masks` list for further processing.
#
# So, `label` is created based on the count of white pixels in the masks associated with each nodule, with a threshold of `Thres`. If the count exceeds the threshold, it's considered as a positive case (`1`), otherwise, it's considered as a negative case (`0`).

# %%
images=np.array(images)/255
masks=np.array(masks)/255
label=np.array(y)
print(images.shape)
print(masks.shape)
print(label.shape)
# Out:
# (10011, 128, 128, 3)
# (10011, 128, 128, 3)
# (10011,)

# %%
yy=pd.DataFrame(label)
yy.value_counts()
# Out:
# 1    5097
# 0    4914
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test,mask_train,mask_test = train_test_split(images,label,masks,train_size=0.8, random_state=7)
print(x_train.shape)
print(mask_train.shape)
# Out:
# (8008, 128, 128, 3)
# (8008, 128, 128, 3)

# %%
images = np.nan_to_num(images)
masks = np.nan_to_num(masks )
np.isnan(masks).sum()
masks.shape
# Out:
# (10011, 128, 128, 3)

# %%
x_train_added = np.vstack([x_train,x_test[:2000]])
y_train_added = np.concatenate((y_train,y_test[:2000]))
print(x_test.shape)
print(mask_test.shape)
Name='vgg19_custom'
# Out:
# (2003, 128, 128, 3)
# (2003, 128, 128, 3)

# %%
def mean_iou(y_true, y_pred):
    # Define a function to calculate IoU
    def iou(y_true, y_pred):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + K.epsilon()) / (union + K.epsilon()), axis=0)
        return iou
    
    # Compute IoU for each class
    ious = iou(y_true, y_pred)
    # Take the mean over classes (excluding the background)
    return K.mean(ious)

# Define the Matthews correlation coefficient (MCC) custom metric function
def mcc(y_true, y_pred):
    y_pred_pos = tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = tf.keras.backend.sum(y_pos * y_pred_pos)
    tn = tf.keras.backend.sum(y_neg * y_pred_neg)

    fp = tf.keras.backend.sum(y_neg * y_pred_pos)
    fn = tf.keras.backend.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = tf.keras.backend.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn) + tf.keras.backend.epsilon())

    return numerator / (denominator + tf.keras.backend.epsilon())

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Accuracy, Recall, Precision, AUC, MeanIoU
import tensorflow.keras.backend as K

def vgg19_model(input_shape):
    # Load pre-trained VGG19 model without the top classification layers
    vgg19_base = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the layers of the VGG19 model
    for layer in vgg19_base.layers:
        layer.trainable = False

    # Additional convolutional layers for better feature representation
    conv1 = Conv2D(512, (3, 3), activation='relu', padding='same')(vgg19_base.output)
    conv2 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv1)
    conv3 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv2)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv3)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)

    # Upsampling layers to match the target label dimensions
    upsample1 = UpSampling2D(size=(16, 16))(conv5)  # Adjusted to match (128, 128) target size
    upsample2 = UpSampling2D(size=(2, 2))(upsample1)  # Adjusted to match (128, 128) target size

    # Output layer
    outputs = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(upsample2)

    # Create model
    model = Model(inputs=vgg19_base.input, outputs=outputs, name='vgg19_custom')
    return model

# Assuming input shape (height, width, channels) as (128, 128, 3)
input_shape = (128, 128, 3)
vgg19_custom = vgg19_model(input_shape)

def mean_iou(y_true, y_pred):
    # Define a function to calculate IoU
    def iou(y_true, y_pred):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + K.epsilon()) / (union + K.epsilon()), axis=0)
        return iou
    
    # Compute IoU for each class
    ious = iou(y_true, y_pred)
    # Take the mean over classes (excluding the background)
    return K.mean(ious)

vgg19_custom.compile(optimizer='adam', loss='binary_crossentropy', metrics=[Accuracy(), Recall(), Precision(), AUC(), mean_iou,mcc])
vgg19_custom.summary()
# Out:
# Model: "vgg19_custom"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  conv2d (Conv2D)             (None, 4, 4, 512)         2359808
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 512)       0
#  D)
#
#  up_sampling2d_1 (UpSamplin  (None, 128, 128, 512)     0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 3)       13827
#
# =================================================================
# Total params: 31837251 (121.45 MB)
# Trainable params: 11812867 (45.06 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
with tf.device('/gpu:0'):
     results = vgg19_custom.fit(x_train, mask_train, validation_data=(x_test, mask_test), batch_size=32, epochs=150)
# Out:
# Epoch 1/150
# 251/251 [==============================] - 1101s 4s/step - loss: 0.0298 - accuracy: 0.0000e+00 - recall: 0.0039 - precision: 0.0082 - auc: 0.8874 - mean_iou: 0.0129 - mcc: 0.0014 - val_loss: 0.0241 - val_accuracy: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.9436 - val_mean_iou: 0.0192 - val_mcc: 0.0000e+00
# Epoch 2/150
# 251/251 [==============================] - 1093s 4s/step - loss: 0.0232 - accuracy: 0.0000e+00 - recall: 4.2363e-04 - precision: 0.4355 - auc: 0.9245 - mean_iou: 0.0176 - mcc: 0.0038 - val_loss: 0.0220 - val_accuracy: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val
# Epoch 33/150
# 251/251 [==============================] - 1090s 4s/step - loss: 0.0178 - accuracy: 0.0152 - recall: 0.0409 - precision: 0.6961 - auc: 0.9743 - mean_iou: 0.0417 - mcc: 0.1647 - val_loss: 0.0197 - val_accuracy: 0.0165 - val_recall: 0.0304 - val_precision: 0.6722 - val_auc: 0.9530 - val_mean_iou: 0.0374 - val_mcc: 0.1430
# Epoch 34/150
# 251/251 [==============================] - 1094s 4s/step - loss: 0.0178 - accuracy: 0.0158 - recall: 0.0409 - precision: 0.7000 - auc: 0.9744 - mean_iou: 0.0400 - mcc: 0.1652 - val_loss: 0.0203 - val_accuracy: 0.0052 - val_recall: 0.0351 - val_precision: 0.6301 - val_auc: 0.9529 - val_mean_iou: 0.0387 - val_mcc: 0.1470
# Epoch 35/150
# 251/251 [==============================] - 1095s 4s/step - loss: 0.0178 - accuracy: 0.0105 - recall: 0.0396 - precision: 0.6962 - auc: 0.9740 - mean_iou: 0.0436 - mcc: 0.1638 - val_loss: 0.0196 - val_accuracy: 0.0080 - val_recall: 0.0324 - val_precision: 0.6477 - val_auc: 0.9601 - val_mean_iou: 0.0335 - val_mcc: 0.1441
# Epoch 36/150
# 251/251 [==============================] - 1090s 4s/step - loss: 0.0176 - accuracy: 0.0111 - recall: 0.0433 - precision: 0.6889 - auc: 0.9753 - mean_iou: 0.0449 - mcc: 0.1682 - val_loss: 0.0200 - val_accuracy: 0.0120 - val_recall: 0.0301 - val_precision: 0.6896 - val_auc: 0.9432 - val_mean_iou: 0.0492 - val_mcc: 0.1434
# Epoch 37/150
# 251/251 [==============================] - 1097s 4s/step - loss: 0.0177 - accuracy: 0.0097 - recall: 0.0411 - precision: 0.7003 - auc: 0.9751 - mean_iou: 0.0457 - mcc: 0.1673 - val_loss: 0.0203 - val_accuracy: 0.0113 - val_recall: 0.0269 - val_precision: 0.7115 - val_auc: 0.9432 - val_mean_iou: 0.0452 - val_mcc: 0.1384
# Epoch 38/150
# 251/251 [==============================] - 1092s 4s/step - loss: 0.0177 - accuracy: 0.0164 - recall: 0.0400 - precision: 0.7016 - auc: 0.9739 - mean_iou: 0.0464 - mcc: 0.1648 - val_loss: 0.0202 - val_accuracy: 0.0152 - val_recall: 0.0276 - val_precision: 0.7102 - val_auc: 0.9453 - val_mean_iou: 0.0490 - val_mcc: 0.1392
# Epoch 39/150
# 251/251 [==============================] - 1092s 4s/step - loss: 0.0177 - accuracy: 0.0177 - recall: 0.0430 - precision: 0.6908 - auc: 0.9748 - mean_iou: 0.0493 - mcc: 0.1681 - val_loss: 0.0200 - val_accuracy: 0.0167 - val_recall: 0.0331 - val_precision: 0.6593 - val_auc: 0.9533 - val_mean_iou: 0.0431 - val_mcc: 0.1465
# Epoch 40/150
# 251/251 [==============================] - 1094s 4s/step - loss: 0.0177 - accuracy: 0.0280 - recall: 0.0420 - precision: 0.6980 - auc: 0.9749 - mean_iou: 0.0542 - mcc: 0.1689 - val_loss: 0.0205 - val_accuracy: 0.0169 - val_recall: 0.0270 - val_precision: 0.7010 - val_auc: 0.9378 - val_mean_iou: 0.0391 - val_mcc: 0.1377
# Epoch 41/150
# 251/251 [==============================] - 1094s 4s/step - loss: 0.0176 - accuracy: 0.0251 - recall: 0.0396 - precision: 0.7126 - auc: 0.9754 - mean_iou: 0.0523 - mcc: 0.1655 - val_loss: 0.0203 - val_accuracy: 0.0247 - val_recall: 0.0253 - val_precision: 0.7302 - val_auc: 0.9437 - val_mean_iou: 0.0383 - val_mcc: 0.1358
# Epoch 42/150
# 251/251 [==============================] - 1100s 4s/step - loss: 0.0178 - accuracy: 0.0331 - recall: 0.0404 - precision: 0.7001 - auc: 0.9738 - mean_iou: 0.0425 - mcc: 0.1642 - val_loss: 0.0198 - val_accuracy: 0.0352 - val_recall: 0.0273 - val_precision: 0.7053 - val_auc: 0.9488 - val_mean_iou: 0.0345 - val_mcc: 0.1384
# Epoch 43/150
# 251/251 [==============================] - 1093s 4s/step - loss: 0.0177 - accuracy: 0.0447 - recall: 0.0410 - precision: 0.7001 - auc: 0.9747 - mean_iou: 0.0527 - mcc: 0.1660 - val_loss: 0.0199 - val_accuracy: 0.0312 - val_recall: 0.0275 - val_precision: 0.7213 - val_auc: 0.9510 - val_mean_iou: 0.0407 - val_mcc: 0.1407
# Epoch 44/150
# 251/251 [==============================] - 1101s 4s/step - loss: 0.0176 - accuracy: 0.0436 - recall: 0.0422 - precision: 0.7059 - auc: 0.9760 - mean_iou: 0.0567 - mcc: 0.1689 - val_loss: 0.0200 - val_accuracy: 0.0526 - val_recall: 0.0280 - val_precision: 0.7135 - val_auc: 0.9474 - val_mean_iou: 0.0658 - val_mcc: 0.1408
# Epoch 45/150
# 251/251 [==============================] - 1101s 4s/step - loss: 0.0175 - accuracy: 0.0515 - recall: 0.0432 - precision: 0.6976 - auc: 0.9761 - mean_iou: 0.0763 - mcc: 0.1716 - val_loss: 0.0208 - val_accuracy: 0.0321 - val_recall: 0.0275 - val_precision: 0.7022 - val_auc: 0.9337 - val_mean_iou: 0.0559 - val_mcc: 0.1390
# Epoch 46/150
# 251/251 [==============================] - 1100s 4s/step - loss: 0.0176 - accuracy: 0.0422 - recall: 0.0433 - precision: 0.7037 - auc: 0.9757 - mean_iou: 0.0658 - mcc: 0.1715 - val_loss: 0.0199 - val_accuracy: 0.0258 - val_recall: 0.0302 - val_precision: 0.6880 - val_auc: 0.9527 - val_mean_iou: 0.0522 - val_mcc: 0.1445
# Epoch 47/150
# 251/251 [==============================] - 1104s 4s/step - loss: 0.0176 - accuracy: 0.0429 - recall: 0.0441 - precision: 0.6976 - auc: 0.9759 - mean_iou: 0.0783 - mcc: 0.1719 - val_loss: 0.0200 - val_accuracy: 0.0337 - val_recall: 0.0308 - val_precision: 0.6766 - val_auc: 0.9521 - val_mean_iou: 0.0513 - val_mcc: 0.1435
# Epoch 48/150
# Epoch 64/150
# 251/251 [==============================] - 1099s 4s/step - loss: 0.0173 - accuracy: 0.1037 - recall: 0.0469 - precision: 0.7018 - auc: 0.9778 - mean_iou: 0.1741 - mcc: 0.1783 - val_loss: 0.0206 - val_accuracy: 0.0946 - val_recall: 0.0300 - val_precision: 0.7072 - val_auc: 0.9436 - val_mean_iou: 0.1456 - val_mcc: 0.1447
# Epoch 65/150
# 251/251 [==============================] - 1095s 4s/step - loss: 0.0173 - accuracy: 0.1058 - recall: 0.0481 - precision: 0.7016 - auc: 0.9781 - mean_iou: 0.2158 - mcc: 0.1797 - val_loss: 0.0208 - val_accuracy: 0.0898 - val_recall: 0.0317 - val_precision: 0.6879 - val_auc: 0.9440 - val_mean_iou: 0.1664 - val_mcc: 0.1460
# Epoch 66/150
# 251/251 [==============================] - 1545s 6s/step - loss: 0.0173 - accuracy: 0.1109 - recall: 0.0489 - precision: 0.6938 - auc: 0.9780 - mean_iou: 0.2338 - mcc: 0.1802 - val_loss: 0.0210 - val_accuracy: 0.0972 - val_recall: 0.0329 - val_precision: 0.6672 - val_auc: 0.9434 - val_mean_iou: 0.1725 - val_mcc: 0.1466
# Epoch 67/150
# 251/251 [==============================] - 1104s 4s/step - loss: 0.0173 - accuracy: 0.1185 - recall: 0.0480 - precision: 0.6991 - auc: 0.9781 - mean_iou: 0.2203 - mcc: 0.1790 - val_loss: 0.0210 - val_accuracy: 0.0820 - val_recall: 0.0322 - val_precision: 0.6817 - val_auc: 0.9415 - val_mean_iou: 0.1191 - val_mcc: 0.1466
# Epoch 68/150
# 251/251 [==============================] - 1098s 4s/step - loss: 0.0173 - accuracy: 0.1141 - recall: 0.0476 - precision: 0.6989 - auc: 0.9777 - mean_iou: 0.1907 - mcc: 0.1782 - val_loss: 0.0210 - val_accuracy: 0.1069 - val_recall: 0.0312 - val_precision: 0.6920 - val_auc: 0.9409 - val_mean_iou: 0.1784 - val_mcc: 0.1460
# Epoch 69/150
# 251/251 [==============================] - 1087s 4s/step - loss: 0.0177 - accuracy: 0.1105 - recall: 0.0428 - precision: 0.6946 - auc: 0.9745 - mean_iou: 0.1169 - mcc: 0.1698 - val_loss: 0.0210 - val_accuracy: 0.1289 - val_recall: 0.0246 - val_precision: 0.7300 - val_auc: 0.9311 - val_mean_iou: 0.0568 - val_mcc: 0.1342
# Epoch 70/150
# 251/251 [==============================] - 1082s 4s/step - loss: 0.0176 - accuracy: 0.1319 - recall: 0.0420 - precision: 0.7130 - auc: 0.9756 - mean_iou: 0.1086 - mcc: 0.1713 - val_loss: 0.0207 - val_accuracy: 0.1276 - val_recall: 0.0330 - val_precision: 0.6670 - val_auc: 0.9433 - val_mean_iou: 0.1242 - val_mcc: 0.1466
# Epoch 71/150
# 251/251 [==============================] - 1085s 4s/step - loss: 0.0174 - accuracy: 0.1500 - recall: 0.0477 - precision: 0.6951 - auc: 0.9774 - mean_iou: 0.1494 - mcc: 0.1772 - val_loss: 0.0208 - val_accuracy: 0.1415 - val_recall: 0.0312 - val_precision: 0.6955 - val_auc: 0.9424 - val_mean_iou: 0.1150 - val_mcc: 0.1452
# Epoch 134/150
# 251/251 [==============================] - 1105s 4s/step - loss: 0.0171 - accuracy: 0.2823 - recall: 0.0493 - precision: 0.7060 - auc: 0.9794 - mean_iou: 0.3564 - mcc: 0.1832 - val_loss: 0.0227 - val_accuracy: 0.2540 - val_recall: 0.0296 - val_precision: 0.7120 - val_auc: 0.9376 - val_mean_iou: 0.2911 - val_mcc: 0.1450
# Epoch 135/150
# 251/251 [==============================] - 1125s 4s/step - loss: 0.0171 - accuracy: 0.2994 - recall: 0.0500 - precision: 0.7041 - auc: 0.9795 - mean_iou: 0.3788 - mcc: 0.1835 - val_loss: 0.0222 - val_accuracy: 0.2594 - val_recall: 0.0307 - val_precision: 0.6927 - val_auc: 0.9411 - val_mean_iou: 0.2699 - val_mcc: 0.1460
# Epoch 136/150
# 251/251 [==============================] - 1790s 7s/step - loss: 0.0171 - accuracy: 0.3151 - recall: 0.0498 - precision: 0.7064 - auc: 0.9796 - mean_iou: 0.3852 - mcc: 0.1841 - val_loss: 0.0225 - val_accuracy: 0.2734 - val_recall: 0.0304 - val_precision: 0.7010 - val_auc: 0.9394 - val_mean_iou: 0.2938 - val_mcc: 0.1461
# Epoch 137/150
# 251/251 [==============================] - 1788s 7s/step - loss: 0.0171 - accuracy: 0.3235 - recall: 0.0487 - precision: 0.7126 - auc: 0.9795 - mean_iou: 0.3897 - mcc: 0.1832 - val_loss: 0.0220 - val_accuracy: 0.2709 - val_recall: 0.0311 - val_precision: 0.6983 - val_auc: 0.9441 - val_mean_iou: 0.2738 - val_mcc: 0.1476
# Epoch 138/150
# 251/251 [==============================] - 1775s 7s/step - loss: 0.0171 - accuracy: 0.3265 - recall: 0.0510 - precision: 0.6985 - auc: 0.9793 - mean_iou: 0.3758 - mcc: 0.1851 - val_loss: 0.0224 - val_accuracy: 0.2680 - val_recall: 0.0302 - val_precision: 0.6980 - val_auc: 0.9427 - val_mean_iou: 0.2857 - val_mcc: 0.1451
# Epoch 139/150
# 251/251 [==============================] - 1777s 7s/step - loss: 0.0172 - accuracy: 0.3092 - recall: 0.0487 - precision: 0.7014 - auc: 0.9790 - mean_iou: 0.3566 - mcc: 0.1812 - val_loss: 0.0212 - val_accuracy: 0.2500 - val_recall: 0.0327 - val_precision: 0.6756 - val_auc: 0.9506 - val_mean_iou: 0.2179 - val_mcc: 0.1483
# Epoch 140/150
# 251/251 [==============================] - 1764s 7s/step - loss: 0.0173 - accuracy: 0.2835 - recall: 0.0457 - precision: 0.7114 - auc: 0.9778 - mean_iou: 0.2896 - mcc: 0.1772 - val_loss: 0.0206 - val_accuracy: 0.2183 - val_recall: 0.0316 - val_precision: 0.6610 - val_auc: 0.9507 - val_mean_iou: 0.1690 - val_mcc: 0.1445
# Epoch 141/150
# 251/251 [==============================] - 1096s 4s/step - loss: 0.0174 - accuracy: 0.3132 - recall: 0.0455 - precision: 0.7041 - auc: 0.9774 - mean_iou: 0.2416 - mcc: 0.1762 - val_loss: 0.0204 - val_accuracy: 0.1103 - val_recall: 0.0292 - val_precision: 0.6416 - val_auc: 0.9536 - val_mean_iou: 0.0370 - val_mcc: 0.1364
# Epoch 150/150
# 251/251 [==============================] - 1089s 4s/step - loss: 0.0177 - accuracy: 0.2764 - recall: 0.0427 - precision: 0.6908 - auc: 0.9740 - mean_iou: 0.0938 - mcc: 0.1692 - val_loss: 0.0213 - val_accuracy: 0.2929 - val_recall: 0.0298 - val_precision: 0.7104 - val_auc: 0.9433 - val_mean_iou: 0.1599 - val_mcc: 0.1453

# %%
vgg19_custom.save(Name+'.h5')
model = vgg19_custom
# Out:
# c:\Users\nidhi\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pd.DataFrame.from_dict(results.history).to_csv(Name+'new.csv',index=False)

# %%
new_impr= vgg19_custom.predict(x_train)
# Out:
# 251/251 [==============================] - 338s 1s/step

# %%
img_id=1019
new_img= np.array(x_train[img_id])
plt.imshow(x_train[img_id])
plt.axis('off')
plt.tight_layout()
plt.show()
plt.imshow(mask_train[img_id])
plt.axis('off')
plt.tight_layout()
plt.show()
new_img = new_img.reshape(1,128,128,3)
new_impr= vgg19_custom.predict(new_img)
plt.imshow(new_impr[0])
plt.axis('off')
plt.tight_layout()
#plt.savefig("Activation_Layer5D7"+'.png')
plt.show()
# Out:
# 1/1 [==============================] - 0s 92ms/step

# %%
new_impr[1000]
# Out:
# array([[[1.17185615e-29, 1.53884872e-29, 3.48825485e-29],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.97522758e-29, 1.11820624e-28, 8.61114755e-29]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[2.59283711e-27, 3.11920629e-27, 5.51969249e-27],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[2.59283711e-27, 3.11920629e-27, 5.51969249e-27],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[1.33582018e-18, 1.52475743e-18, 3.21635740e-18],
#         [3.54986059e-27, 1.66158527e-27, 3.13706967e-27],
#         [3.54986059e-27, 1.66158527e-27, 3.13706967e-27],
#         ...,
#         [3.60922580e-37, 2.00940393e-37, 7.71848019e-37],
#         [3.60922580e-37, 2.00940393e-37, 7.71848019e-37],
#         [4.29212207e-19, 3.34306492e-19, 4.00555362e-19]]], dtype=float32)

# %%
img_id=1789
fig = plt.figure(figsize=(10,10))
a = fig.add_subplot(3, 1, 1)
plt.imshow(x_train[img_id])
#a.set_title("original",fontsize=10)
plt.axis('off')
a = fig.add_subplot(3, 1, 2)
plt.imshow(mask_train[img_id])
#a.set_title("True Mask",fontsize=10)
plt.axis('off')
a = fig.add_subplot(3, 1, 3)
plt.imshow(new_impr[img_id],interpolation='nearest')
#a.set_title("Predicted",fontsize=10)
plt.axis('off')
plt.tight_layout()
plt.savefig("Segmentation"+str(img_id)+'.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Get training results
accuracy = results.history['accuracy']
val_accuracy = results.history['val_accuracy']
loss = results.history['loss']
val_loss = results.history['val_loss']

# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(accuracy, label='Training Accuracy', color='blue')
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def plot_accuracy(history):
    # Get training and validation accuracy values
    train_acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # Plot training and validation accuracy
    epochs = range(1, len(train_acc) + 1)
    plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# Example usage:
# Assuming 'history' contains the training history of your model
# You can obtain 'history' by calling model.fit() during training
# model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10, batch_size=32)
history = vgg19_custom.history
plot_accuracy(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 21
#      16 # Example usage:
#      17 # Assuming 'history' contains the training history of your model
#      18 # You can obtain 'history' by calling model.fit() during training
#      19 # model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10, batch_size=32)
#      20 history = vgg19_custom.history
# ---> 21 plot_accuracy(history)
#
# Cell In[23], line 3, in plot_accuracy(history)
#       1 def plot_accuracy(history):
#       2     # Get training and validation accuracy values
# ----> 3     train_acc = history.history['accuracy']
#       4     val_acc = history.history['val_accuracy']
#       6     # Plot training and validation accuracy
#
# KeyError: 'accuracy'

# %%
mask_train = vgg19_custom.predict(x_train)
# Out:
# 251/251 [==============================] - 361s 1s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Generate predictions for the test set
predictions = vgg19_custom.predict(x_test)

# 2. Convert predictions to binary masks (if needed)
# Example thresholding (adjust threshold value as needed)
threshold = 0.66
predictions_binary = (predictions > threshold).astype(np.uint8)

# Flatten the predictions to match the shape of y_test
# Reshape predictions_binary to match the shape of y_test
y_score = predictions_binary.max(axis=(1, 2, 3))

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_score)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 63/63 [==============================] - 85s 1s/step

# %%
import numpy as np

# Calculate misclassification rate
misclassification_rate = (conf_matrix[0, 1] + conf_matrix[1, 0]) / np.sum(conf_matrix)

print("Misclassification rate:", misclassification_rate)
# Out:
# Misclassification rate: 0.17923115327009487

# %%
from sklearn.metrics import roc_curve, auc


# Assuming y_test contains the true labels
fpr, tpr, thresholds = roc_curve(y_test, y_score)

# Compute AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Calculate precision and recall
precision, recall, _ = precision_recall_curve(y_test, y_score)

# Plot the Precision-Recall Curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()

# %%
import numpy as np
import tensorflow.keras.backend as K

def mean_iou(y_true, y_pred):
    # Define a function to calculate IoU
    def iou(y_true, y_pred):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + K.epsilon()) / (union + K.epsilon()), axis=0)
        return iou
    
    # Compute IoU for each class
    ious = iou(y_true, y_pred)
    # Take the mean over classes (excluding the background)
    return K.mean(ious)

# Compile your model with mIoU as a metric
vgg19_custom.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', mean_iou])

# %%
from sklearn.metrics import classification_report

# Assuming y_true and y_pred are your true labels and predicted labels, respectively
# y_true and y_pred should be 1D arrays containing the predicted class labels for each sample

# Classification report
print(classification_report(y_test, y_score))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       932
#            1       0.86      0.79      0.83      1071
#
#     accuracy                           0.82      2003
#    macro avg       0.82      0.82      0.82      2003
# weighted avg       0.82      0.82      0.82      2003
